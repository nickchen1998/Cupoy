# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
'''
Your Code
r.text 所讀出來的資料，整串接為字串的型態，可以看到最外層包了' '
因此需要使用 json.loads(r.text) 將資料轉換為 python 看得懂的型態
'''
# Out:
# '\nYour Code\n'

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
'''
Your Code
'''
import requests, json

#由於上述兩個連結都無法使用，因此爬取康是美門市地址
url = 'https://www.cosmed.com.tw/api/getStore.aspx?t=store&c=&d=&s='
r = requests.get(url)

print(json.loads(r.text))
# Out:
# {'data': [{'StoreID': '00107122', 'StoreNM': '台大門市', 'ZipCode': '10000', 'ZipCodeName1': '臺北市', 'ZipCodeName2': '中正區', 'Address': '羅斯福路四段84號1樓+2樓', 'Tel': '02-23675542', 'Fax': '02-23687056', 'BizHrsMonS': '0900', 'BizHrsMonE': '2300', 'BizHrsSatS': '0900', 'BizHrsSatE': '2300', 'BizHrsSunS': '0900', 'BizHrsSunE': '2300', 'HolidayClosed': 'N', 'StoreType': '1', 'Taxfree': 'Y', 'Wechat': 'Y', 'Prescription': '', 'Wifi': '', 'Brands': 'AHC|Dr.Jart+|DR.WU|IM MEME|TUNEMAKERS|ZA|巴黎歐樹NUXE|艾杜紗 ettusais|貝膚黛瑪BIODERMA|妮傲絲翠NeoStrata|花漾美姬KISSME|派翠PEZRI|美肌醫生DF|珂莉奧CLIO|珂潤Curél|專科|凱婷 KATE|媚點 media|雅漾Avéne|潔美淨Physiogel|適樂膚CeraVe|樹予saeve|霓淨思Neogence|蘇菲娜 SOFINA|櫻特芮 INTEGRATE|', 'Pic': '107122.jpg', 'lat': '25.014', 'lng': '121.534745'}, {'StoreID': '00101124', 'StoreNM': '站前門市', 'ZipCode': '10041', 'ZipCodeName1': '臺北市', 'ZipCodeName2': '中正區', 'Address': '忠孝西路一段49號地下B1(南港線台北車站５號販賣店)', 'Tel': '02-23117690', 'Fax': '02-23893716', 'BizHrsMonS': '0700', 'BizHrsMonE': '2300', 'BizHrsSatS': '0700', 'BizHrsSatE': '2300', 'BizHrsSunS': '0700', 'BizHrsSunE': '2300', 'HolidayClosed': 'N', 'StoreType': '1', 'Taxfree': 'Y', 'Wechat': 'Y', 'Prescription': '', 'Wifi': '', 'Brands': '1028|AHC|Catrice|Dr.Jart+|DR.WU|EXCEL|flormar|IM MEME|MAJOLICA|Solone|TUNEMAKERS|XOXO|ZA|巴黎歐樹NUXE|艾杜紗 ettusais|貝膚黛瑪BIODERMA|妮傲絲翠NeoStrata|花漾美姬KISSME|派翠PEZRI|美肌醫生DF|珂莉奧CLIO|珂潤Curél|專科|凱婷 KATE|媚點 media|雅漾Avéne|資生堂專櫃|潔美淨Physiogel|適樂膚CeraVe|樹予saeve|霓淨思Neogence|蘇菲娜 SOFINA|', 'Pic': '101124.png', 'lat': '25.0463846', 'lng': '121.5178642'}, {'StoreID': '00106048', 'StoreNM': '北車門市', 'ZipCode': '10041', 'ZipCodeName1': '臺北市', 'ZipCodeName2': '中正區', 'Address': '忠孝西路一段49號B3層', 'Tel': '02-23117477', 'Fax': '02-23115347', 'BizHrsMonS': '0700', 'BizHrsMonE': '2300', 'BizHrsSatS': '0700', 'BizHrsSatE': '2300', 'BizHrsSunS': '0700', 'BizHrsSunE': '2300', 'HolidayClosed': 'N', 'StoreType': '1', 'Taxfree': 'Y', 'Wechat': 'Y', 'Prescription': '', 'Wifi': '', 'Brands': 'AHC|Catrice|Dr.Jart+|DR.WU|flormar|KOKIE|pretty by flormar|TUNEMAKERS|XOXO|巴黎歐樹NUXE|艾杜紗 ettusais|貝膚黛瑪BIODERMA|妮傲絲翠NeoStrata|派翠PEZRI|美肌醫生DF|珂莉奧CLIO|珂潤Curél|凱婷 KATE|媚點 media|雅漾Avéne|潔美淨Physiogel|適樂膚CeraVe|樹予saeve|霓淨思Neogence|櫻特芮 INTEGRATE|', 'Pic': '106048.png', 'lat': '25.0463846', 'lng': '121.5178642'}, {'StoreID': '00105241', 'StoreNM': '風采門市', 'ZipCode': '10043', 'ZipCodeName1': '臺北市', 'ZipCodeName2': '中正區', 'Address': '延平南路103號1~3樓', 'Tel': '02-23701411', 'Fax': '02-23705543', 'BizHrsMonS': '0800', 'BizHrsMonE': '2300', 'BizHrsSatS': '0900', 'BizHrsSatE': '2300', 'BizHrsSunS': '0900', 'BizHrsSunE': '2300', 'HolidayClosed': 'N', 'StoreType': '1', 'Taxfree': 'Y', 'Wechat': 'Y', 'Prescription': '', 'Wifi': '', 'Brands': 'AHC|Andreia|ANGFA 絲凱露D|CNP|Dr.Jart+|DR.WU|flormar|freeplus|KOKIE|MAJOLICA|MEKO|QV|Solone|TUNEMAKERS|ZA|巴黎歐樹NUXE|艾杜紗 ettusais|貝膚黛瑪BIODERMA|妮傲絲翠NeoStrata|花漾美姬KISSME|派翠PEZRI|美肌醫生DF|珂莉奧CLIO|珂潤Curél|專科|凱婷 KATE|媚點 media|雅漾Avéne|潔美淨Physiogel|適樂膚CeraVe|樹予saeve|霓淨思Neogence|寵愛之名|蘇菲娜 SOFINA|櫻特芮 INTEGRATE|', 'Pic': '105241.jpg', 'lat': '25.04209', 'lng': '121.509665'}, {'StoreID': '00950562', 'StoreNM': '新中正門市', 'ZipCode': '10057', 'ZipCodeName1': '臺北市', 'ZipCodeName2': '中正區', 'Address': '信義路二段1號1、2樓', 'Tel': '02-23967058', 'Fax': '02-23515950', 'BizHrsMonS': '0800', 'BizHrsMonE': '2300', 'BizHrsSatS': '0800', 'BizHrsSatE': '2300', 'BizHrsSunS': '0800', 'BizHrsSunE': '2300', 'HolidayClosed': 'N', 'StoreType': '1', 'Taxfree': '', 'Wechat': '', 'Prescription': '', 'Wifi': '', 'Brands': 'AHC|CNP|Dr.Jart+|DR.WU|freeplus|QV|TUNEMAKERS|巴黎歐樹NUXE|貝膚黛瑪BIODERMA|妮傲絲翠NeoStrata|派翠PEZRI|美肌醫生DF|珂莉奧CLIO|珂潤Curél|專科|凱婷 KATE|媚點 media|雅漾Avéne|潔美淨Physiogel|適樂膚CeraVe|樹予saeve|霓淨思Neogence|蘇菲娜 SOFINA|櫻特芮 INTEGRATE|', 'Pic': '950562.jpg', 'lat': '25.0354941', 'lng': '121.5248911'}, {'StoreID': '00910117', 'StoreNM': '寧波門市', 'ZipCode': '10074', 'ZipCodeName1': '臺北市', 'ZipCodeName2': '中正區', 'Address': '寧波西街11號', 'Tel': '02-23432427', 'Fax': '02-23968818', 'BizHrsMonS': '0800', 'BizHrsMonE': '2200', 'BizHrsSatS': '0800', 'BizHrsSatE': '2200', 'BizHrsSunS': ...
