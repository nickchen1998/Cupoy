# %% [markdown]
# # 作業: 安裝MongoDB、Robo 3T 工具

# %% [markdown]
# # [作業目標]
# * 成功安裝 Mongo資料庫及GUI工具
# * 能夠使用命令提示工具(cmd、terminal)操作Mongo資料
# * 能夠使用 Robo 3T 操作Mongo資料

# %% [markdown]
# # [作業重點]
# * 了解 DB、Collection、Document 在 Mongo 中所代表的意義。
# * 能夠手動對資料做增刪改查的操作。

# %% [markdown]
# # [作業1]
# * 至以下網站下載 MongoDB 和 Robo 3T 工具，並成功運行。
#
# Mongo: https://www.mongodb.com/try/download/community
#
# Robo 3T: https://robomongo.org/

# %% [markdown]
# # [作業2]
# * 分別使用命令提示工具、Robo 3T圖形介面工具，照以下步驟操作資料。
#
#
# 1. 新增一個 DB 名稱自訂。
# 2. 在該 DB 中新增一個 Collection 名稱為 Member
# 3. 在 Collection 中新增一筆會員資料，資料結構如下：
#     * name : Kevin
#     * email : test@abc.com
#     * phone: 0912345678
# 4. 將上述那筆資料的 name 欄位改成 Cathy
# 5. 加入新的欄位 age 到上述那筆資料中，並將值的部分設為 25
#
# `註: 請將作業結果截圖下來。`

# %% [markdown]
# ## 1. 使用 Robo 3T

# %% [markdown]
# ![ROBO3T%20%E7%B7%A8%E8%BC%AF.PNG](attachment:ROBO3T%20%E7%B7%A8%E8%BC%AF.PNG)

# %% [markdown]
# ![ROBO3T%20%E6%9F%A5%E8%A9%A2.PNG](attachment:ROBO3T%20%E6%9F%A5%E8%A9%A2.PNG)

# %% [markdown]
# ## 2. 使用 mongo shell

# %% [markdown]
# ![image.png](attachment:image.png)
